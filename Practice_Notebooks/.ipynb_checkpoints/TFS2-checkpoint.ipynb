# %% [markdown]
# # Read & Plot Time Series Data

# %%
import pandas as pd
import datetime as dt
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from patsy import dmatrices
from pandas import Series
from matplotlib import pyplot
from datetime import datetime
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 12), dpi=80, facecolor='w', edgecolor='k')

# %% [markdown]
# # Read yearly time series: USGDP

# %%
USGDP = pd.read_csv('GDPUS.csv', header=0)
USGDP.head(8)
# Out:
#    Year    GDP
# 0  1929  821.8
# 1  1930  748.9
# 2  1931  691.3
# 3  1932  599.7
# 4  1933  587.1
# 5  1934  632.6
# 6  1935  681.6
# 7  1936  777.9

# %%
USGDP.tail(5)
# Out:
#     Year     GDP
# 58  1987  4718.6
# 59  1988  4784.6
# 60  1989  4739.2
# 61  1990  4822.3
# 62  1991  4835.0

# %%
date_rng = pd.date_range(start='1/1/1929', end='31/12/1991', freq='Y') #Freq is most imp feature, it is yearly data(Y)
date_rng
# Out:
# DatetimeIndex(['1929-12-31', '1930-12-31', '1931-12-31', '1932-12-31',
#                '1933-12-31', '1934-12-31', '1935-12-31', '1936-12-31',
#                '1937-12-31', '1938-12-31', '1939-12-31', '1940-12-31',
#                '1941-12-31', '1942-12-31', '1943-12-31', '1944-12-31',
#                '1945-12-31', '1946-12-31', '1947-12-31', '1948-12-31',
#                '1949-12-31', '1950-12-31', '1951-12-31', '1952-12-31',
#                '1953-12-31', '1954-12-31', '1955-12-31', '1956-12-31',
#                '1957-12-31', '1958-12-31', '1959-12-31', '1960-12-31',
#                '1961-12-31', '1962-12-31', '1963-12-31', '1964-12-31',
#                '1965-12-31', '1966-12-31', '1967-12-31', '1968-12-31',
#                '1969-12-31', '1970-12-31', '1971-12-31', '1972-12-31',
#                '1973-12-31', '1974-12-31', '1975-12-31', '1976-12-31',
#                '1977-12-31', '1978-12-31', '1979-12-31', '1980-12-31',
#                '1981-12-31', '1982-12-31', '1983-12-31', '1984-12-31',
#                '1985-12-31', '1986-12-31', '1987-12-31', '1988-12-31',
#                '1989-12-31', '1990-12-31', '1991-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
USGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year']) #Adding the time index 
USGDP.head(8)
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31
# 5  1934  632.6 1934-12-31
# 6  1935  681.6 1935-12-31
# 7  1936  777.9 1936-12-31

# %%
plt.plot(USGDP.TimeIndex, USGDP.GDP)
plt.legend(loc='best')
pyplot.show() #Every year it is increasing except for some year (Trend), It is the world war time between 1944-1947

# %% [markdown]
# # Task 1: Read GDP India series

# %%
INGDP = pd.read_csv('GDPIndia.csv', header=0)
INGDP.head(8) #This is percapita GDP
# Out:
#    Year  GDPpercapita
# 0  1960     81.284764
# 1  1961     84.426437
# 2  1962     88.914919
# 3  1963    100.048592
# 4  1964    114.315161
# 5  1965    118.063382
# 6  1966     89.053583
# 7  1967     95.330783

# %%
INGDP.tail(5)
# Out:
#     Year  GDPpercapita
# 53  2013   1452.195373
# 54  2014   1576.004018
# 55  2015   1606.038285
# 56  2016   1717.473878
# 57  2017   1939.612984

# %%
date_rng = pd.date_range(start='1/1/1960', end='31/12/2017', freq='Y') 
date_rng
# Out:
# DatetimeIndex(['1960-12-31', '1961-12-31', '1962-12-31', '1963-12-31',
#                '1964-12-31', '1965-12-31', '1966-12-31', '1967-12-31',
#                '1968-12-31', '1969-12-31', '1970-12-31', '1971-12-31',
#                '1972-12-31', '1973-12-31', '1974-12-31', '1975-12-31',
#                '1976-12-31', '1977-12-31', '1978-12-31', '1979-12-31',
#                '1980-12-31', '1981-12-31', '1982-12-31', '1983-12-31',
#                '1984-12-31', '1985-12-31', '1986-12-31', '1987-12-31',
#                '1988-12-31', '1989-12-31', '1990-12-31', '1991-12-31',
#                '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31',
#                '1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
#                '2012-12-31', '2013-12-31', '2014-12-31', '2015-12-31',
#                '2016-12-31', '2017-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
INGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year']) #Adding the time index 
INGDP.head(8)
# Out:
#    Year  GDPpercapita  TimeIndex
# 0  1960     81.284764 1960-12-31
# 1  1961     84.426437 1961-12-31
# 2  1962     88.914919 1962-12-31
# 3  1963    100.048592 1963-12-31
# 4  1964    114.315161 1964-12-31
# 5  1965    118.063382 1965-12-31
# 6  1966     89.053583 1966-12-31
# 7  1967     95.330783 1967-12-31

# %%
plt.plot(INGDP.TimeIndex, INGDP.GDPpercapita)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Read Quarterly Time Series: Retail Turnover

# %%
Turnover = pd.read_csv('RetailTurnover.csv')
#Turnover.head()

# %%
from datetime import datetime
date_rng = pd.date_range(start='1/7/1982', end='31/3/1992', freq='Q')

# %%
date_rng
# Out:
# DatetimeIndex(['1982-03-31', '1982-06-30', '1982-09-30', '1982-12-31',
#                '1983-03-31', '1983-06-30', '1983-09-30', '1983-12-31',
#                '1984-03-31', '1984-06-30', '1984-09-30', '1984-12-31',
#                '1985-03-31', '1985-06-30', '1985-09-30', '1985-12-31',
#                '1986-03-31', '1986-06-30', '1986-09-30', '1986-12-31',
#                '1987-03-31', '1987-06-30', '1987-09-30', '1987-12-31',
#                '1988-03-31', '1988-06-30', '1988-09-30', '1988-12-31',
#                '1989-03-31', '1989-06-30', '1989-09-30', '1989-12-31',
#                '1990-03-31', '1990-06-30', '1990-09-30', '1990-12-31',
#                '1991-03-31', '1991-06-30', '1991-09-30', '1991-12-31',
#                '1992-03-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
Turnover['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Turnover.head()
# Out:
#    Year Quarter  Turnover  TimeIndex
# 0  1982      Q3   13423.2 1982-03-31
# 1  1982      Q4   13128.8 1982-06-30
# 2  1983      Q1   15398.8 1982-09-30
# 3  1983      Q2   12964.2 1982-12-31
# 4  1983      Q3   13133.5 1983-03-31

# %%
plt.plot(Turnover.TimeIndex, Turnover.Turnover)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 3: Read Portugal Port Series

# %%
Port = pd.read_csv('PortugalPort.csv')

# %%
Port.head()
# Out:
#    Year Quarter  Pax
# 0  2000      Q1   21
# 1  2000      Q2   61
# 2  2000      Q3  119
# 3  2000      Q4   30
# 4  2001      Q1   16

# %%
from datetime import datetime
date_rng = pd.date_range(start='1/3/2000', end='31/10/2017', freq='Q')

# %%
Port['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Port.head()
# Out:
#    Year Quarter  Pax  TimeIndex
# 0  2000      Q1   21 2000-03-31
# 1  2000      Q2   61 2000-06-30
# 2  2000      Q3  119 2000-09-30
# 3  2000      Q4   30 2000-12-31
# 4  2001      Q1   16 2001-03-31

# %%
plt.plot(Port.Time, Port.Pax)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 4: Read Petrol Consumption Series

# %% [markdown]
# # Read Monthly Time Series: Average Monthly Temperature

# %%
AirTemp = pd.read_csv('AirTemp.csv')
#AirTemp.head()

# %%
date_rng = pd.date_range(start='1/1/1920', end='31/12/1939', freq='M')
#date_rng

# %%
AirTemp['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirTemp.head()
# Out:
#    Year Month  AvgTemp  TimeIndex
# 0  1920   Jan     40.6 1920-01-31
# 1  1920   Feb     40.8 1920-02-29
# 2  1920   Mar     44.4 1920-03-31
# 3  1920   Apr     46.7 1920-04-30
# 4  1920   May     54.1 1920-05-31

# %%
plt.plot(AirTemp.TimeIndex, AirTemp.AvgTemp)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 5: Read Champagne Series

# %%
Chp = pd.read_csv('Champagne.csv')

# %%
date_rng = pd.date_range(start='1/1/1964', end='30/9/1972', freq='M')

# %%
Chp['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
Chp.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
plt.plot(Chp.TimeIndex, Chp.Sales)
plt.legend(loc='best')
pyplot.show()

# %%
Chp_sales = pd.pivot_table(Chp, values = "Sales",columns="Month",index="Year")
Chp_sales.plot() #Additive

# %% [markdown]
# # Task 6: Read International Air Passengers Data

# %% [markdown]
# # Task 7: Read Tractor Sales Series

# %%
Tractor = pd.read_csv("TractorSales.csv")
Tractor.head(5)
# Out:
#   Month-Year  Number of Tractor Sold
# 0      3-Jan                     141
# 1      3-Feb                     157
# 2      3-Mar                     185
# 3      3-Apr                     199
# 4      3-May                     203

# %%
dates = pd.date_range(start='2003-01-01', freq='MS', periods=len(Tractor)) #This is 2003 data 3 Jan Means

# %%
import calendar
Tractor['Month'] = dates.month
Tractor['Month'] = Tractor['Month'].apply(lambda x: calendar.month_abbr[x])
Tractor['Year'] = dates.year

# %%
#Tractor.drop(['Month-Year'], axis=1, inplace=True)
Tractor.rename(columns={'Number of Tractor Sold':'Tractor-Sales'}, inplace=True)
Tractor = Tractor[['Month', 'Year', 'Tractor-Sales']]

# %%
Tractor.set_index(dates, inplace=True)

# %%
Tractor.head(5)
# Out:
#            Month  Year  Tractor-Sales
# 2003-01-01   Jan  2003            141
# 2003-02-01   Feb  2003            157
# 2003-03-01   Mar  2003            185
# 2003-04-01   Apr  2003            199
# 2003-05-01   May  2003            203

# %%
# extract out the time-series
sales_ts = Tractor['Tractor-Sales']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('Tractor Sales')
# Out:
# Text(0, 0.5, 'Tractor Sales')

# %%
monthly_tractor = pd.pivot_table(Tractor, values = "Tractor-Sales",columns="Month",index="Year")
monthly_tractor.plot()

# %%
monthly_tractor.boxplot()

# %% [markdown]
# # Task 8: Read Environmental CO2 Emission Series

# %% [markdown]
# # Task 9: Reading Retal Food Sales Series

# %% [markdown]
# # Task 10: Reading Mauna Loa Emission Series

# %% [markdown]
# # Reading Weekly Time Series: Dow Jones Closing

# %%
DJI = pd.read_csv("WeeklyClosing.csv")
DJI.head(5)
# Out:
#          Week  Closing
# 0  1971-07-05   890.19
# 1  1971-07-12   901.80
# 2  1971-07-19   888.51
# 3  1971-07-26   887.78
# 4  1971-08-02   858.43

# %%
date_rng = pd.date_range(start='7/4/1971', end='8/5/1974', freq='W')
DJI['TimeIndex'] = pd.DataFrame(date_rng, columns=['Week'])
DJI.rename(columns={'DJIA Closing':'Closing'}, inplace=True)
DJI.head()
# Out:
#          Week  Closing  TimeIndex
# 0  1971-07-05   890.19 1971-07-04
# 1  1971-07-12   901.80 1971-07-11
# 2  1971-07-19   888.51 1971-07-18
# 3  1971-07-26   887.78 1971-07-25
# 4  1971-08-02   858.43 1971-08-01

# %%
plt.plot(DJI.TimeIndex, DJI.Closing)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 11: Reading Gasoline Price Data

# %% [markdown]
# # Read Week-Day Time Series: Crude Oil Production

# %%
CrdOil = pd.read_csv('CrudeOil.csv')
CrdOil.head()
# Out:
#          Date  Weekday  Price
# 0  1983-04-04        2  29.44
# 1  1983-04-05        3  29.71
# 2  1983-04-06        4  29.92
# 3  1983-04-07        5  30.17
# 4  1983-04-08        6  30.38

# %%
date_rng = pd.date_range(start='4/4/1983', end='27/11/2012', freq='B')
#date_rng

# %%
CrdOil['TimeIndex'] = pd.DataFrame(date_rng, columns=['Weekday'])
CrdOil.head()
# Out:
#          Date  Weekday  Price  TimeIndex
# 0  1983-04-04        2  29.44 1983-04-04
# 1  1983-04-05        3  29.71 1983-04-05
# 2  1983-04-06        4  29.92 1983-04-06
# 3  1983-04-07        5  30.17 1983-04-07
# 4  1983-04-08        6  30.38 1983-04-08

# %%
plt.plot(CrdOil.TimeIndex, CrdOil.Price)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Simple Forecasts: Average and Moving Average

# %% [markdown]
# # AirTemp, US GDP, India GDP, Eng Daily Wage

# %%
temp_avg = AirTemp.copy()
temp_avg['avg_forecast'] = AirTemp['AvgTemp'].mean()

# %%
plt.figure(figsize=(12,8))
plt.plot(AirTemp['AvgTemp'], label='Data')
plt.plot(temp_avg['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')

# %%
mvg_avg = AirTemp.copy()
mvg_avg['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(12).mean()
#mvg_avg.head(15)
#mvg_avg.tail(6)

# %%
#plt.figure(figsize=(16,8))
plt.plot(AirTemp['AvgTemp'], label='Average Temperature')
plt.plot(mvg_avg['moving_avg_forecast'], label='Moving Average Forecast')
plt.legend(loc='best')

# %% [markdown]
# # Task 1: MA(5) for US GDP

# %%
mvg_avg_USGDP = USGDP.copy()
mvg_avg_USGDP['moving_avg_forecast']= USGDP['GDP'].rolling(5).mean()
plt.plot(USGDP['GDP'],label='US GDP')
plt.plot(mvg_avg_USGDP['moving_avg_forecast'],label=['US GDP'])
plt.legend(loc='best')

# %% [markdown]
# # Task 2: MA(3) for India GDP

# %% [markdown]
# # Task 2: MA(7) for Daily Wage

# %% [markdown]
# # MA Forecast for Crude Oil

# %%
mvg_avg_oil1 = CrdOil.copy()
mvg_avg_oil2 = CrdOil.copy()
mvg_avg_oil3 = CrdOil.copy()

mvg_avg_oil1['moving_avg_forecast'] = CrdOil['Price'].rolling(300).mean()
mvg_avg_oil2['moving_avg_forecast'] = CrdOil['Price'].rolling(900).mean()
mvg_avg_oil3['moving_avg_forecast'] = CrdOil['Price'].rolling(1500).mean()

# %%
plt.figure(figsize=(16,8))
plt.plot(CrdOil['Price'], label='Crude Oil Price')
plt.plot(mvg_avg_oil1['moving_avg_forecast'], label='MA(300)')
plt.plot(mvg_avg_oil2['moving_avg_forecast'], label='MA(900)')
plt.plot(mvg_avg_oil3['moving_avg_forecast'], label='MA(1500)')
plt.legend(loc='upper left')

# %% [markdown]
# # Visualization of Seasonality: Quarterly Turnover

# %%
quarterly_turnover = pd.pivot_table(Turnover, values = "Turnover", columns = "Quarter", index = "Year")
quarterly_turnover
# Out:
# Quarter       Q1       Q2       Q3       Q4
# Year
# 1982         NaN      NaN  13423.2  13128.8
# 1983     15398.8  12964.2  13133.5  13271.7
# 1984     15596.3  13018.0  13409.3  13304.2
# 1985     15873.9  13366.5  13998.6  14045.1
# 1986     16650.3  13598.4  14183.2  14128.5
# 1987     16380.7  13512.8  14022.1  14231.8
# 1988     16737.0  14004.5  14165.5  14203.9
# 1989     16895.1  14248.2  14719.5  14855.8
# 1990     17361.6  14585.2  14873.5  14798.4
# 1991     17115.2  14284.9  14558.8  14914.3
# 1992     17342.3      NaN      NaN      NaN

# %%
quarterly_turnover.plot()

# %%
quarterly_turnover.boxplot()

# %% [markdown]
# # Task 1: Seasonality of Portugal Port

# %%
quarterly_portpax = pd.pivot_table(Port, values = "Pax",columns="Quarter",index="Year")
quarterly_portpax.plot()

# %%
quarterly_portpax.boxplot()

# %% [markdown]
# # Task 2: Seasonality of Petrol Consumption

# %%
Petrol = pd.read_csv('Petrol.csv')

# %%
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
quarterly_portpax = pd.pivot_table(Petrol, values = "Consumption",columns="Quarter",index="Year")
quarterly_portpax.plot()

# %%
quarterly_portpax.boxplot()

# %% [markdown]
# # Visualization of Seasonality: Monthly Temperature

# %%
monthly_temp = pd.pivot_table(AirTemp, values = "AvgTemp", columns = "Month", index = "Year")
monthly_temp = monthly_temp[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
monthly_temp
# Out:
# Month   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1920   40.6  40.8  44.4  46.7  54.1  58.5  57.7  56.4  54.3  50.5  42.9  39.8
# 1921   44.2  39.8  45.1  47.0  54.1  58.7  66.3  59.9  57.0  54.2  39.7  42.8
# 1922   37.5  38.7  39.5  42.1  55.7  57.8  56.8  54.3  54.3  47.1  41.8  41.7
# 1923   41.8  40.1  42.9  45.8  49.2  52.7  64.2  59.6  54.4  49.2  36.6  37.6
# 1924   39.3  37.5  38.3  45.5  53.2  57.7  60.8  58.2  56.4  49.8  44.4  43.6
# 1925   40.0  40.5  40.8  45.1  53.8  59.4  63.5  61.0  53.0  50.0  38.1  36.3
# 1926   39.2  43.4  43.4  48.9  50.6  56.8  62.5  62.0  57.5  46.7  41.6  39.8
# 1927   39.4  38.5  45.3  47.1  51.7  55.0  60.4  60.5  54.7  50.3  42.3  35.2
# 1928   40.8  41.1  42.8  47.3  50.9  56.4  62.2  60.5  55.4  50.2  43.0  37.3
# 1929   34.8  31.3  41.0  43.9  53.1  56.9  62.5  60.3  59.8  49.2  42.9  41.9
# 1930   41.6  37.1  41.2  46.9  51.2  60.4  60.1  61.6  57.0  50.9  43.0  38.8
# 1931   37.1  38.4  38.4  46.5  53.5  58.4  60.6  58.2  53.8  46.6  45.5  40.6
# 1932   42.4  38.4  40.3  44.6  50.9  57.0  62.1  63.5  56.2  47.3  43.6  41.8
# 1933   36.2  39.3  44.5  48.7  54.2  60.8  65.5  64.9  60.1  50.2  42.1  35.6
# 1934   39.4  38.2  40.4  46.9  53.4  59.6  66.5  60.4  59.2  51.2  42.8  45.8
# 1935   40.4  42.6  43.5  47.1  50.0  60.5  64.6  64.0  56.8  48.6  44.2  36.4
# 1936   37.3  35.0  44.0  43.9  52.7  58.6  60.0  61.1  58.1  49.6  41.6  41.3
# 1937   40.8  41.0  38.4  47.4  54.1  58.6  61.4  61.8  56.3  50.9  41.4  37.1
# 1938   42.1  41.2  47.3  46.6  52.4  59.0  59.6  60.4  57.0  50.7  47.8  39.2
# 1939   39.4  40.9  42.4  47.8  52.4  58.0  60.7  61.8  58.2  46.7  46.6  37.8

# %%
monthly_temp.plot()

# %%
monthly_temp.boxplot()

# %% [markdown]
# # Task 3: Seasonality of Champagne Sales

# %% [markdown]
# # Task 4: Seasonality of Air Passengers

# %%
passenger = pd.read_csv('AirPax.csv')

# %%
passenger.head()
# Out:
#    Year Month  Pax
# 0  1949   Jan  112
# 1  1949   Feb  118
# 2  1949   Mar  132
# 3  1949   Apr  129
# 4  1949   May  121

# %%
quarterly_airpax = pd.pivot_table(passenger, values = "Pax",columns="Month",index="Year")
quarterly_airpax.plot() #July has highest and feb has least #multiplicative

# %%
quarterly_airpax.boxplot()

# %%
monthly_travel = pd.pivot_table(passenger, values = "Pax", columns = "Month", index = "Year")
monthly_travel = monthly_travel[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
monthly_travel
# Out:
# Month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
monthly_travel.boxplot()

# %%
monthly_travel.min()
# Out:
# Month
# Jan    112
# Feb    118
# Mar    132
# Apr    129
# May    121
# Jun    135
# Jul    148
# Aug    148
# Sep    136
# Oct    119
# Nov    104
# Dec    118
# dtype: int64

# %%
monthly_travel.max()
# Out:
# Month
# Jan    417
# Feb    391
# Mar    419
# Apr    461
# May    472
# Jun    535
# Jul    622
# Aug    606
# Sep    508
# Oct    461
# Nov    390
# Dec    432
# dtype: int64

# %%
monthly_travel.plot()

# %% [markdown]
# # Task 5: Seasonality of Tractor Sales

# %% [markdown]
# # Task 6: Seasonality of CO2 Emission

# %% [markdown]
# # Task 7: Seasonality of Retail Food Sales

# %% [markdown]
# # Task 8: Seasonality of MaunaLoa

# %%
MounaLoa = pd.read_csv('MaunaLoa.csv')

# %%
MounaLoa.head()
# Out:
#    Year Month  CO2 ppm
# 0  1965   Jan   319.32
# 1  1965   Feb   320.36
# 2  1965   Mar   320.82
# 3  1965   Apr   322.06
# 4  1965   May   322.17

# %%
Monthly_Co2 = pd.pivot_table(MounaLoa, values = "CO2 ppm",columns="Month",index="Year")
Monthly_Co2.plot()

# %% [markdown]
# # Seasonal Decomposition for turnoverdata

# %%
import statsmodels.api as sm

# %%
decompTurnover = sm.tsa.seasonal_decompose(Turnover.Turnover, model="additive", freq=4) #Quaterly 
decompTurnover.plot()
plt.show()

# %%
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12) #No Residual value in these case
# Out:
# 0            NaN
# 1            NaN
# 2     13692.5375
# 3     13674.1875
# 4     13716.7375
# 5     13748.1500
# 6     13789.3500
# 7     13827.8875
# 8     13866.6500
# 9     13944.9125
# 10    14062.1375
# 11    14228.4125
# Name: Turnover, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0     -524.613498
# 1     -510.713672
# 2     1894.960113
# 3     -859.632943
# 4     -524.613498
# 5     -510.713672
# 6     1894.960113
# 7     -859.632943
# 8     -524.613498
# 9     -510.713672
# 10    1894.960113
# 11    -859.632943
# Name: Turnover, dtype: float64

# %%
residual.head(12)
# Out:
# 0            NaN
# 1            NaN
# 2    -188.697613
# 3     149.645443
# 4     -58.624002
# 5      34.263672
# 6     -88.010113
# 7      49.745443
# 8      67.263498
# 9    -129.998828
# 10    -83.197613
# 11     -2.279557
# Name: Turnover, dtype: float64

# %% [markdown]
# # Seasonal Decomposition Monthly Temp

# %%
plt.plot(AirTemp.TimeIndex, AirTemp.AvgTemp)
plt.legend(loc='best')
pyplot.show()

# %%
decompMonthlyTemp = sm.tsa.seasonal_decompose(AirTemp.AvgTemp,model='additive',freq=12)
decompTurnover.plot()
plt.show()

# %%
trend = decompMonthlyTemp.trend
seasonal = decompMonthlyTemp.seasonal
residual = decompMonthlyTemp.resid

# %%
trend.head(12)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6     49.041667
# 7     49.150000
# 8     49.137500
# 9     49.179167
# 10    49.191667
# 11    49.200000
# Name: AvgTemp, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0     -9.320066
# 1     -9.901645
# 2     -6.948355
# 3     -2.759101
# 4      3.451645
# 5      8.984759
# 6     12.965461
# 7     11.457346
# 8      7.393092
# 9      0.652961
# 10    -6.603618
# 11    -9.372478
# Name: AvgTemp, dtype: float64

# %%
residual.head(12)
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6    -4.307127
# 7    -4.207346
# 8    -2.230592
# 9     0.667873
# 10    0.311952
# 11   -0.027522
# Name: AvgTemp, dtype: float64

# %% [markdown]
# # Seasonal Decomposition AirPax

# %%
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')

# %%
passenger['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year']) #Adding the time index 
passenger.head(8)
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31
# 5  1949   Jun  135 1949-06-30
# 6  1949   Jul  148 1949-07-31
# 7  1949   Aug  148 1949-08-31

# %%
plt.plot(passenger.TimeIndex, passenger.Pax)
plt.legend(loc='best')
pyplot.show()

# %%
decompairpax = sm.tsa.seasonal_decompose(passenger.Pax,model='multiplicative',freq=12)
decompairpax.plot()
plt.show()

# %% [markdown]
# # Sesonal Decomposition of Tractor Sales

# %%
Tractor.columns
# Out:
# Index(['Month', 'Year', 'Tractor-Sales'], dtype='object')

# %%
decomptractorsales = sm.tsa.seasonal_decompose(Tractor['Tractor-Sales'],model='multiplicative',freq=12)
decomptractorsales.plot()
plt.show()

# %%
trend = decomptractorsales.trend
seasonal = decomptractorsales.seasonal
residual = decomptractorsales.resid

# %%
seasonal.head()
# Out:
# 2003-01-01    0.823333
# 2003-02-01    0.843859
# 2003-03-01    1.012370
# 2003-04-01    1.080556
# 2003-05-01    1.185793
# Freq: MS, Name: Tractor-Sales, dtype: float64

# %%
seasonal.head(10)
# Out:
# 2003-01-01    0.823333
# 2003-02-01    0.843859
# 2003-03-01    1.012370
# 2003-04-01    1.080556
# 2003-05-01    1.185793
# 2003-06-01    1.120913
# 2003-07-01    1.236024
# 2003-08-01    1.230135
# 2003-09-01    0.961964
# 2003-10-01    0.836410
# Freq: MS, Name: Tractor-Sales, dtype: float64

# %%
seasonal.head().sum()
# Out:
# 4.945912451555429

# %% [markdown]
# # Seasonal Decomposition of Champagne

# %%
Chp.columns
# Out:
# Index(['Year', 'Month', 'Sales', 'TimeIndex'], dtype='object')

# %%
decompchp = sm.tsa.seasonal_decompose(Chp['Sales'],model='additive',freq=12)
decompchp.plot()
plt.show()             #See from sub plots and orginal plots multiplicative and additive

# %% [markdown]
# # Split Data in Training and Test

# %%
Petrol = pd.read_csv('Petrol.csv')
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng = pd.date_range(start='1/1/2001', end='30/9/2013', freq='Q')
date_rng
Petrol['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Petrol.head()
plt.plot(Petrol.TimeIndex, Petrol.Consumption)
pyplot.show()

# %%
#Creating train and test set 
train=Petrol[0:int(len(Petrol)*0.7)] 
test=Petrol[int(len(Petrol)*0.7):]

# %%
type(train)
train.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
plt.plot(train.Consumption)
plt.plot(test.Consumption)
pyplot.show()

# %%
train.Consumption.plot()
test.Consumption.plot()

# %% [markdown]
# # Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model = SimpleExpSmoothing(np.asarray(train['Consumption']))

# %%
# fit model
model99_fit = model.fit(smoothing_level=0.99,optimized=False) #Alpha = 0.99 (Only value which change to get diff model)
model5_fit = model.fit(smoothing_level=0.5,optimized=False)
model1_fit = model.fit(smoothing_level=0.1,optimized=False)

# %%
fcst_SES = test.copy()

# %%
fcst_SES['SES99'] = model99_fit.forecast(len(test['Consumption']))
fcst_SES['SES5'] = model5_fit.forecast(len(test['Consumption']))
fcst_SES['SES1'] = model1_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_SES['SES99'], label='SES99')
plt.plot(fcst_SES['SES5'], label='SES5')
plt.plot(fcst_SES['SES1'], label='SES1')
plt.legend(loc='best')

# %%
fcst_SES['SES99']
# Out:
# 35    1.986998
# 36    1.986998
# 37    1.986998
# 38    1.986998
# 39    1.986998
# 40    1.986998
# 41    1.986998
# 42    1.986998
# 43    1.986998
# 44    1.986998
# 45    1.986998
# 46    1.986998
# 47    1.986998
# 48    1.986998
# 49    1.986998
# 50    1.986998
# Name: SES99, dtype: float64

# %%
#
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_SES['SES99'])
# Out:
# 94.50460480680182

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_SES['SES99']))
rmse
# Out:
# 0.9437879263674692

# %%
model_opt_fit = model.fit()

# %%
model_opt_fit.model.params #Smoothing Level
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': nan,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 14.978,
#  'initial_slope': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
plt.plot(model99_fit.fittedvalues,label="Fits1")
plt.plot(model5_fit.fittedvalues,label="Fits2")
plt.plot(model1_fit.fittedvalues,label="Fits3")
plt.legend(loc="best")

# %% [markdown]
# # Double Exponential (Holt)

# %%
model = Holt(np.asarray(train['Consumption']))
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False) #Alpha=0.3, Beta=0.1

# %%
model31_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)

# %%
fcst_Holt = test.copy()

# %%
fcst_Holt['Holt31'] = model31_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Holt31'], label='Holt31')
plt.legend(loc='best')

# %%
modelopt_fit = model.fit()

# %%
fcst_Holt['Opt'] = modelopt_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Opt'], label='HoltOpt')
plt.legend(loc='best')

# %%
modelopt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': 0.019969000242354897,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 15.12712291257399,
#  'initial_slope': 0.0,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %% [markdown]
#    # Forecast USGDP for 5 years

# %%
USGDP = pd.read_csv('GDPUS.csv', header=0)
USGDP.head(8)
# Out:
#    Year    GDP
# 0  1929  821.8
# 1  1930  748.9
# 2  1931  691.3
# 3  1932  599.7
# 4  1933  587.1
# 5  1934  632.6
# 6  1935  681.6
# 7  1936  777.9

# %%
date_rng = pd.date_range(start='1/1/1929', end='31/12/1991', freq='Y') #Freq is most imp feature, it is yearly data(Y)
date_rng
# Out:
# DatetimeIndex(['1929-12-31', '1930-12-31', '1931-12-31', '1932-12-31',
#                '1933-12-31', '1934-12-31', '1935-12-31', '1936-12-31',
#                '1937-12-31', '1938-12-31', '1939-12-31', '1940-12-31',
#                '1941-12-31', '1942-12-31', '1943-12-31', '1944-12-31',
#                '1945-12-31', '1946-12-31', '1947-12-31', '1948-12-31',
#                '1949-12-31', '1950-12-31', '1951-12-31', '1952-12-31',
#                '1953-12-31', '1954-12-31', '1955-12-31', '1956-12-31',
#                '1957-12-31', '1958-12-31', '1959-12-31', '1960-12-31',
#                '1961-12-31', '1962-12-31', '1963-12-31', '1964-12-31',
#                '1965-12-31', '1966-12-31', '1967-12-31', '1968-12-31',
#                '1969-12-31', '1970-12-31', '1971-12-31', '1972-12-31',
#                '1973-12-31', '1974-12-31', '1975-12-31', '1976-12-31',
#                '1977-12-31', '1978-12-31', '1979-12-31', '1980-12-31',
#                '1981-12-31', '1982-12-31', '1983-12-31', '1984-12-31',
#                '1985-12-31', '1986-12-31', '1987-12-31', '1988-12-31',
#                '1989-12-31', '1990-12-31', '1991-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
USGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year']) #Adding the time index 
USGDP.head(8)
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31
# 5  1934  632.6 1934-12-31
# 6  1935  681.6 1935-12-31
# 7  1936  777.9 1936-12-31

# %%
train=USGDP[0:int(len(Petrol)*0.7)] 
test=USGDP[int(len(Petrol)*0.7):]

# %%
model = Holt(np.asarray(train['GDP']))
model_fit = model.fit(smoothing_level = 0.3,smoothing_slope = 0.1,optimized=False)

# %%
FCST_Holt = test.copy()

# %%
FCST_Holt['Holt'] = model_fit.forecast(len(test['GDP']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['GDP'], label='Train')
plt.plot(test['GDP'], label='Test')
plt.plot(FCST_Holt['Holt'], label='Holt')
plt.legend(loc='best')

# %%
modelopt_fit = model.fit()

# %%
FCST_Holt['Opt'] = modelopt_fit.forecast(len(test['GDP']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['GDP'], label='Train')
plt.plot(test['GDP'], label='Test')
plt.plot(FCST_Holt['Opt'], label='HoltOpt')
plt.legend(loc='best')

# %%
modelopt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': 0.9213621725759392,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 857.7322536939657,
#  'initial_slope': 0.0,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
FCTS_SES['SES'] = model_fit.forecast(len(test['GDP']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-242-71118659afb8> in <module>()
# ----> 1 FCTS_SES['SES'] = model_fit.forecast(len(test['GDP']))
#
# NameError: name 'FCTS_SES' is not defined

# %%
# For getting the forecast create an array and like 5 values then predict

# %%
mean_absolute_percentage_error(test['GDP'],fcst_SES['SES'])

# %% [markdown]
# # Champagne Data

# %%
Chp = pd.read_csv('Champagne.csv')

# %%
date_rng = pd.date_range(start='1/1/1964', end='30/9/1972', freq='M')

# %%
Chp['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
Chp.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
train = Chp.head(84)
test = Chp.tail(21)

# %%
train
# Out:
#     Year Month  Sales  TimeIndex
# 0   1964   Jan   2815 1964-01-31
# 1   1964   Feb   2672 1964-02-29
# 2   1964   Mar   2755 1964-03-31
# 3   1964   Apr   2721 1964-04-30
# 4   1964   May   2946 1964-05-31
# 5   1964   Jun   3036 1964-06-30
# 6   1964   Jul   2282 1964-07-31
# 7   1964   Aug   2212 1964-08-31
# 8   1964   Sep   2922 1964-09-30
# 9   1964   Oct   4301 1964-10-31
# 10  1964   Nov   5764 1964-11-30
# 11  1964   Dec   7312 1964-12-31
# 12  1965   Jan   2541 1965-01-31
# 13  1965   Feb   2475 1965-02-28
# 14  1965   Mar   3031 1965-03-31
# 15  1965   Apr   3266 1965-04-30
# 16  1965   May   3776 1965-05-31
# 17  1965   Jun   3230 1965-06-30
# 18  1965   Jul   3028 1965-07-31
# 19  1965   Aug   1759 1965-08-31
# 20  1965   Sep   3595 1965-09-30
# 21  1965   Oct   4474 1965-10-31
# 22  1965   Nov   6838 1965-11-30
# 23  1965   Dec   8357 1965-12-31
# 24  1966   Jan   3113 1966-01-31
# 25  1966   Feb   3006 1966-02-28
# 26  1966   Mar   4047 1966-03-31
# 27  1966   Apr   3523 1966-04-30
# 28  1966   May   3937 1966-05-31
# 29  1966   Jun   3986 1966-06-30
# ..   ...   ...    ...        ...
# 54  1968   Jul   3965 1968-07-31
# 55  1968   Aug   1723 1968-08-31
# 56  1968   Sep   5048 1968-09-30
# 57  1968   Oct   6922 1968-10-31
# 58  1968   Nov   9858 1968-11-30
# 59  1968   Dec  11331 1968-12-31
# 60  1969   Jan   4016 1969-01-31
# 61  1969   Feb   3957 1969-02-28
# 62  1969   Mar   4510 1969-03-31
# 63  1969   Apr   4276 1969-04-30
# 64  1969   May   4968 1969-05-31
# 65  1969   Jun   4677 1969-06-30
# 66  1969   Jul   3523 1969-07-31
# 67  1969   Aug   1821 1969-08-31
# 68  1969   Sep   5222 1969-09-30
# 69  1969   Oct   6872 1969-10-31
# 70  1969   Nov  10803 1969-11-30
# 71  1969   Dec  13916 1969-12-31
# 72  1970   Jan   2639 1970-01-31
# 73  1970   Feb   2899 1970-02-28
# 74  1970   Mar   3370 1970-03-31
# 75  1970   Apr   3740 1970-04-30
# 76  1970   May   2927 1970-05-31
# 77  1970   Jun   3986 1970-06-30
# 78  1970   Jul   4217 1970-07-31
# 79  1970   Aug   1738 1970-08-31
# 80  1970   Sep   5221 1970-09-30
# 81  1970   Oct   6424 1970-10-31
# 82  1970   Nov   9842 1970-11-30
# 83  1970   Dec  13076 1970-12-31
#
# [84 rows x 4 columns]

# %%
model_fit = ExponentialSmoothing(np.asarray(Chp['Sales']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.2, smoothing_seasonal=0.1, smoothing_level = 0.3, optimized=False)

# %%
modelopt_fit = ExponentialSmoothing(np.asarray(Chp['Sales']),  seasonal_periods=12,seasonal='add').fit(optimized=True)

# %%
fcst_HoltW = test.copy()
fcst_HoltW['HoltWM'] = modelopt_fit.forecast(len(test['Sales']))

# %%
mean_absolute_percentage_error(test['Sales'],fcst_HoltW['HoltWM'])
# Out:
# 77.6266972322327

# %%
fcst_HoltW = test.copy()
fcst_HoltW['HoltW'] = model_fit.forecast(len(test['Sales']))
plt.figure(figsize=(16,8))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters')
plt.legend(loc='best')

# %%
fcst_HoltW = test.copy()
fcst_HoltW['HoltW'] = model_fit.forecast(len(test['Sales']))

# %%
mean_absolute_percentage_error(test['Sales'],fcst_HoltW['HoltW'])
# Out:
# 68.19766840467184

# %%
fcst_HoltW = test.copy()
fcst_HoltW['HoltWM'] = modelopt_fit.forecast(len(test['Sales']))

# %%
ean_absolute_percentage_error(test['Sales'],fcst_HoltW['HoltWM'])
# Out:
# 77.6266972322327

# %%
fcst_HoltW['HoltWM'] = modelopt_fit.forecast(len(test['Sales']))
plt.figure(figsize=(16,8))
plt.plot(train['Sales'], label='Train')
plt.plot(test['Sales'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters Additive')
plt.plot(fcst_HoltW['HoltWM'], label='HoltWinters Multiplicative')
plt.legend(loc='best')

# %% [markdown]
# # Air Passenger

# %%
df = pd.read_csv('AirPax.csv')

# %%
df.head()
# Out:
#    Year Month  Pax
# 0  1949   Jan  112
# 1  1949   Feb  118
# 2  1949   Mar  132
# 3  1949   Apr  129
# 4  1949   May  121

# %%
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')

# %%
df['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
df.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
train = df.head(120)
test = df.head(24)

# %%
test.shape
# Out:
# (24, 4)

# %%
train.shape
# Out:
# (120, 4)

# %%
model_fitH= ExponentialSmoothing(np.asarray(train['Pax']),  seasonal_periods=12,seasonal='mul').fit(optimized=True)

# %%
fsct_HoltW = test.copy()

# %%
fsct_HoltW.shape
# Out:
# (24, 4)

# %%
fsct_HoltW.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
test.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31
